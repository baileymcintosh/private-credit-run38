# %% [markdown]
# # Deep analysis of the private credit industry in 2025-2026. Cover: market size and recent growth trajectory (AUM by manag — All Charts
#
# *4 charts generated by the quantitative agent.*

# %% [markdown]
# ### 01 Chart 01

# %%
# 01 Chart 01

# %% [markdown]
# ### Chart Market Impact

# %%
# Chart Market Impact

# %% [markdown]
# ### Chart Scenarios

# %%
# Chart Scenarios

# %% [markdown]
# ### Chart Timeline

# %%
# Chart Timeline
